# %% [markdown]
# <a href="https://colab.research.google.com/github/brad1379/Movie-Recommendation-System/blob/master/Collaborative_Filtering_with_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Collaborative-Based Filtering

# %% [markdown]
# ### Load the data

# %%
import pandas as pd

# %%
ratings = pd.read_csv("ratings.csv")[['userId', 'movieId', 'rating']]
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %% [markdown]
# ### Create the dataset

# %%
# !pip install 'numpy<2'
# A kernel restart might be required after installing/downgrading numpy for the changes to take effect.
from surprise import Dataset, Reader

# %%
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(ratings, reader)

# %% [markdown]
# ### Build the trainset

# %%
trainset = dataset.build_full_trainset()

# %%
list(trainset.all_ratings())[:10]
# Out:
# [(0, 0, 2.5),
#  (0, 1, 3.0),
#  (0, 2, 3.0),
#  (0, 3, 2.0),
#  (0, 4, 4.0),
#  (0, 5, 2.0),
#  (0, 6, 2.0),
#  (0, 7, 2.0),
#  (0, 8, 3.5),
#  (0, 9, 2.0)]

# %% [markdown]
# ### Train the model

# %%
from surprise import SVD


svd = SVD()

# %%
svd.fit(trainset)

# %%
svd.predict(15, 1956)
# Out:
# Prediction(uid=15, iid=1956, r_ui=None, est=3.540380907059295, details={'was_impossible': False})

# %% [markdown]
# ### Validation

# %%
from surprise import model_selection

model_selection.cross_validate(svd, dataset, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.89344504, 0.89870833, 0.88957928, 0.90493006, 0.8973116 ]),
#  'test_mae': array([0.68836652, 0.69219555, 0.68531193, 0.69763575, 0.68954493]),
#  'fit_time': (2.2770962715148926,
#   1.3009905815124512,
#   1.3431038856506348,
#   1.3649775981903076,
#   1.3250126838684082),
#  'test_time': (0.24154925346374512,
#   0.10289883613586426,
#   0.23479533195495605,
#   0.10445404052734375,
#   0.21374750137329102)}
